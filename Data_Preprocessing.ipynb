# %% [markdown]
# ## MISSING VALUES

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Keara\Downloads\Intro_Data_Science_with_Python\automobile.csv")

# %%
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
df_auto = df

# %%
#replace ? with nan
df = df.replace('?', np.nan) 
print(df.isnull().sum().sum())
# Out:
# 59

# %%
#print column names with nan
print(df.isnull().sum())
print([col for col in df.columns if df[col].isnull().any()])
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64
# ['normalized-losses', 'num-of-doors', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']

# %%
#REMOVING NAN
#normalized losses
print(df['normalized-losses'])

df_temp = df[df['normalized-losses'].notnull()]
print(df_temp)
print(df_temp.isnull().sum())
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2               164   audi       gas        std         four
# 4            2               164   audi       gas        std         four
# 6            1               158   audi       gas        std         four
# 8            1               158   audi       gas      turbo         four
# 10           2               192    bmw       gas        std          two
# ..         ...               ...    ...       ...        ...          ...
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# ...

# %%
#IMPUTATION WITH MEAN
#print column types
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#mean of normalized losses
print(df_temp['normalized-losses'].astype(int).mean())

col_mean = df_temp['normalized-losses'].astype(int).mean()
# Out:
# 122.0

# %%
#impute mean
df['normalized-losses'] = df['normalized-losses'].replace(np.nan, col_mean).astype(int)

# %%
#IMPUTATION WITH MEDIAN
#peak rpm
print(df['peak-rpm'])

df_temp = df[df['peak-rpm'].notnull()]
print(df_temp)
print(df_temp.isnull().sum())
# Out:
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peak-rpm, Length: 205, dtype: object
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            3                122  alfa-romero       gas        std
# 2            1                122  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# ...

# %%
#print column types
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#median of peak-rpm
print(df_temp['peak-rpm'].astype(int).median())

col_med = df_temp['peak-rpm'].astype(int).median()

#impute median
df['peak-rpms'] = df['peak-rpm'].replace(np.nan, col_med).astype(int)
# Out:
# 5200.0

# %%
#bore
print(df['bore'])

df_temp = df[df['bore'].notnull()]
print(df_temp)
print(df_temp.isnull().sum())
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: object
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            3                122  alfa-romero       gas        std
# 2            1                122  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# ...

# %%
#print column types
print(df.dtypes)

#mean of bore
print(df_temp['bore'].astype(float).mean())

col_mean = df_temp['bore'].astype(float).mean()

#impute mean
df['bore'] = df['bore'].replace(np.nan, col_mean).astype(float)
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# peak-rpms              int32
# dtype: object
# 3.3297512437810957

# %%
#IMPUTATION WITH MOST FREQUENT
#stroke
print(df['stroke'])
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3       3.4
# 4       3.4
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203     3.4
# 204    3.15
# Name: stroke, Length: 205, dtype: object

# %%
df_temp = df[df['stroke'].notnull()]
print(df_temp)
print(df_temp.isnull().sum())
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                122  alfa-romero       gas        std
# 1            3                122  alfa-romero       gas        std
# 2            1                122  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
#print column types
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# peak-rpms              int32
# dtype: object

# %%
#most frequent of stroke
print(df_temp['stroke'].value_counts())
print(df_temp['stroke'].value_counts().index[0])

most_frequent = df_temp['stroke'].value_counts().index[0]
# Out:
# 3.4     20
# 3.23    14
# 3.03    14
# 3.15    14
# 3.39    13
# 2.64    11
# 3.35     9
# 3.29     9
# 3.46     8
# 3.27     6
# 3.5      6
# 3.07     6
# 3.11     6
# 3.41     6
# 3.19     6
# 3.58     6
# 3.64     5
# 3.52     5
# 3.54     4
# 3.86     4
# 3.47     4
# 3.9      3
# 2.9      3
# 4.17     2
# 3.08     2
# 2.68     2
# 2.8      2
# 3.1      2
# 2.19     2
# 3.16     1
# 2.07     1
# 3.21     1
# 2.36     1
# 2.76     1
# 3.12     1
# 2.87     1
# Name: stroke, dtype: int64
# 3.4

# %%
#impute most frequent
df['stroke'] = df['stroke'].replace(np.nan, most_frequent).astype(float)

# %%
#num-of-doors
print(df['num-of-doors'])
# Out:
# 0       two
# 1       two
# 2       two
# 3      four
# 4      four
#        ...
# 200    four
# 201    four
# 202    four
# 203    four
# 204    four
# Name: num-of-doors, Length: 205, dtype: object

# %%
df_temp = df[df['num-of-doors'].notnull()]
print(df_temp['num-of-doors'].value_counts())
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %%
#impute most frequent
df['num-of-doors'] = df['num-of-doors'].fillna(df_temp['num-of-doors'].value_counts().index[0])

print(df.describe())
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          31.681008    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.258244
# std      2.443522   520.680204    41.642693    0.270844    0.314237
# ...
